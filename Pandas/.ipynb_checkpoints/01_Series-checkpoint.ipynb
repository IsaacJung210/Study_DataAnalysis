# %%
# Out:
# Failed to start the Kernel.
#
# Failed to start the Kernel 'base (Python 3.9.7)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. listen EFAULT: bad address in system call argument :::9001
